# %% [markdown]
# ### exploratory notebook

# %%
import pylast
import pickle
import time
import pandas as pd

# %%
with open('user_list.p', 'rb') as f:
    user_list = pickle.load(f)
    
with open('prelim_user_data.p', 'rb') as f:
    user_data = pickle.load(f)

# %% [markdown]
# ## spotipy

# %% [markdown]
# ### combining lastfm, spotify data

# %%
mask = df.user == 'wildaman1'
top10artists = df[mask].artist[:10].values

artist_features_dict = {artist: get_audio_feats_by_artist(artist) for artist in top10artists}

# %% [markdown]
# ### get top songs

# %%
# goal: implement levenshtein distance to validate correct result
# go from lastfm tracks to spotify features for that track
import os
import sys
import json
import spotipy
import webbrowser
import time
import spotipy.util as util
from spotipy.oauth2 import SpotifyClientCredentials

from json.decoder import JSONDecodeError
import Levenshtein.StringMatcher as leven
import numpy as np

# set up spotipy api
client_id='75ceaa8e4ccd4810b1995ee82aafd5e3'
client_secret='04a0d2e14c424f259132ff86275e5503'
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)
sp.trace=False

def get_features(artist_track, tolerance=10, verbose=False):
    """
    artist_track = 'artist name' + 'track name'
    
    returns: dictionary containing echonest features for that tracks
    """
    
    # make query
    results = sp.search(q=artist_track, limit=5)
    
    tracks = results['tracks']['items'] 
    
    # makes sure a match was returned:
    if tracks == []:
        print('no track found for {}'.format(artist_track))
        return 
    
    # make sure we have a convincing match
    best_distance = np.inf
    best_track = None
    for track in tracks:
        val_artist = track['artists'][0]['name']
        val_name = track['name']
        val_string = val_artist + ' ' + val_name
        val_string = val_string.lower()

        true_string = artist_track.lower()

        dist = leven.distance(true_string, val_string)
        
        
        if dist < best_distance:
            
            best_distance = dist
            best_track = track
            best_track_artist_track = val_string
            spotify_string = val_artist + ' ' + val_name
        
        
    if best_distance < tolerance:
        if verbose:
            print('===================')
            print('found match!')
            print('best distance:\t', best_distance)
            print('input:\t', artist_track)
            print('found:\t', spotify_string)
            print('====================')
            print()
        uri = best_track['uri']
        features = sp.audio_features([uri])
        return best_track_artist_track, features
        
    else:
        if verbose:
            print('+++++++++++++++++++')
            print(f'no match for {artist_track}')
            print()
            print('input:\t', artist_track)
            print('found:\t', spotify_string)
            print('+++++++++++++++++++')
        return None
    
test = "Caribou Can't Do Without"
test_dict = get_features(test)

# %% [markdown]
# ### psycopg2 connection

# %%
import psycopg2


connection = psycopg2.connect(user="max",
                              password="password",
                              host="127.0.0.1",
                              port="5432",
                              database="final")
cursor = connection.cursor()

# %%
q = """
INSERT INTO test (customer, count) VALUES (%s,%s)
"""
record_to_insert = ('bill', 15)
cursor.execute(q, record_to_insert)

connection.commit()
count = cursor.rowcount
print (count, "Record inserted successfully into mobile table")
# Out:
# 1 Record inserted successfully into mobile table

# %%
# schema for actual insertion
# ------------------------------------------
# lastfm_user | arist_track | percent_listen 
# ------------------------------------------

q = """
SELECT DISTINCT arist_track FROM lastfm LIMIT 50000;
"""

cursor.execute(q)

cursor.fetchall()

# %%
# schema for spotify data
# ---------------------------------------------------------
# lastfm_artist_track | spotify_artist_track | **features
# ---------------------------------------------------------
# =========================================================

# EXAMPLE:

# [{'danceability': 0.691,
#    'energy': 0.407,
#    'key': 0,
#    'loudness': -9.053,
#    'mode': 1,
#    'speechiness': 0.0473,
#    'acousticness': 0.792,
#    'instrumentalness': 0.642,
#    'liveness': 0.783,
#    'valence': 0.491,
#    'tempo': 128.039,
#    'type': 'audio_features',
#    'id': '3n4M80UmJNHws4ZqdM7KEF',
#    'uri': 'spotify:track:3n4M80UmJNHws4ZqdM7KEF',
#    'track_href': 'https://api.spotify.com/v1/tracks/3n4M80UmJNHws4ZqdM7KEF',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3n4M80UmJNHws4ZqdM7KEF',
#    'duration_ms': 236400,
#    'time_signature': 4}])

q = "DROP TABLE spotify_features"

cursor.execute(q)


q = """
CREATE TABLE spotify_features (
    lastfm_artist_track VARCHAR (255) NOT NULL,
    spotify_artist_track VARCHAR (255) NOT NULL,
    danceability NUMERIC NOT NULL,
    energy NUMERIC NOT NULL,
    key NUMERIC NOT NULL,
    loudness NUMERIC NOT NULL,
    mode NUMERIC NOT NULL,
    speechiness NUMERIC NOT NULL,
    acousticness NUMERIC NOT NULL,
    instrumentalness NUMERIC NOT NULL,
    liveness NUMERIC NOT NULL,
    valence NUMERIC NOT NULL,
    tempo NUMERIC NOT NULL,
    uri VARCHAR (255) NOT NULL,
    analysis_url VARCHAR (255) NOT NULL,
    duration_ms NUMERIC NOT NULL,
    time_signature SMALLINT NOT NULL
);
"""

cursor.execute(q)
connection.commit()

# %%
def make_spotify_row(lastfm_artist_track):
    test_dict = get_features(lastfm_artist_track)
    if test_dict == None:
        return None
    keys = [
        'danceability',
        'energy',
        'key',
        'loudness',
        'mode',
        'speechiness',
        'acousticness',
        'instrumentalness',
        'liveness',
        'valence',
        'tempo',
        'uri',
        'analysis_url',
        'duration_ms',
        'time_signature'
    ]

    spotify_artist_track = test_dict[0]
    d = test_dict[1][0]
    features = tuple(d[key] for key in keys)
    row = (lastfm_artist_track, spotify_artist_track) + features
    return row

make_spotify_row("Caribou Can't Do Without")
# Out:
# ("Caribou Can't Do Without",
#  "caribou can't do without you",
#  0.691,
#  0.407,
#  0,
#  -9.053,
#  1,
#  0.0473,
#  0.792,
#  0.642,
#  0.783,
#  0.491,
#  128.039,
#  'spotify:track:3n4M80UmJNHws4ZqdM7KEF',
#  'https://api.spotify.com/v1/audio-analysis/3n4M80UmJNHws4ZqdM7KEF',
#  236400,
#  4)

# %%
def spotify_insert_row(lastfm_track):
    q = """
    INSERT INTO 
        spotify_features (
            lastfm_artist_track,
            spotify_artist_track,
            danceability,
            energy,
            key,
            loudness,
            mode,
            speechiness,
            acousticness,
            instrumentalness,
            liveness,
            valence,
            tempo,
            uri,
            analysis_url,
            duration_ms,
            time_signature
            ) VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)
    """
    row = make_spotify_row(lastfm_track)
    if row == None:
        return None
        
    cursor.execute(q, row)
    connection.commit()
    
spotify_insert_row('bonobo the keeper')

# %%
q = """
SELECT DISTINCT arist_track FROM lastfm
LIMIT 5;
"""

cursor.execute(q)
lastfm_artist_tracks = cursor.fetchall()
lastfm_artist_tracks
# Out:
# [('𝖍𝖛𝒙𝖛𝖓 Celeste - XXX',),
#  ('💊💊 FUCKBOY ANTHEM',),
#  ("💊💊 HAD MY GUARD UP 2 U (SINCE '92)",),
#  ('💊💊 MASS APPEAL',),
#  ('💊💊 PARO',)]

# %%
# extract string from tuple
lastfm_artist_tracks = [t[0] for t in lastfm_artist_track]
for t in lastfm_artist_tracks:
    spotify_insert_row(t)
# Out:
# no track found for
# no track found for '
# no track found for
# no track found for

# %%
sample_features = []
for track in sample_tracks:
    track = track[0]
    feature = get_features(track, tolerance=5)
    time.sleep(.1)
    if feature:  # if not None
        sample_features.append(feature)
    
# plan for tomorrow:
# new table, track_features

# lastfm_name, spotify_name, *features

# the goal here would to be able to join on lastfm_name

# ---------------------------------------------------------

# also, make backups of code and data tomorrow if possible.
# Out:
# ===================
# found match!
# best distance:	 0
# input:	 Abandon All Ships Shake Your AAS
# found:	 Abandon All Ships Shake Your AAS
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abandon All Ships Strange Love
# found:	 Abandon All Ships Strange Love
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abandon All Ships Structures
# found:	 Abandon All Ships Structures
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abandon All Ships Take One Last Breath
# found:	 Abandon All Ships Take One Last Breath
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abandon All Ships Trapped
# found:	 Abandon All Ships Trapped
# ====================
#
# no track found for Abandon All Ships We'll Be Fine (Drake Cover)
# ===================
# found match!
# best distance:	 0
# input:	 Abandon All Ships When Dreams Become Nightmares
# found:	 Abandon All Ships When Dreams Become Nightmares
# ====================
#
# ===================
# found match!
# best distance:	 1
# input:	 Abandon All Ships brendons song
# found:	 Abandon All Ships Brendon's Song
# ====================
#
# no track found for Abandon All Ships maria (i like it loud) (scooter cover)
# ===================
# found match!
# best distance:	 1
# input:	 Abandon All Ships! Faded
# found:	 Abandon All Ships Faded
# ====================
#
# no track found for Abandon All Ships! Pedestrians Is Another Word For Speedbumb
# ===================
# found match!
# best distance:	 0
# input:	 Abandon Atmosphere
# found:	 Abandon Atmosphere
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abandon Bitter the Surface
# found:	 Abandon Bitter The Surface
# ====================
#
# ===================
# found match!
# best distance:	 4
# input:	 Abandon Eulogy
# found:	 Abandon Eulogy (I)
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abandon Feel It In Your Heart
# found:	 Abandon Feel It In Your Heart
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abandon Hold On
# found:	 Abandon Hold On
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abandon In Hopelessness Enlightened
# found:	 Abandon In Hopelessness Enlightened
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abandon In Reality We Suffer
# found:	 Abandon In Reality We Suffer
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abandon It's All Gone
# found:	 Abandon It's All Gone
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abandon Kansas Chariot
# found:	 Abandon Kansas Chariot
# ====================
#
# ===================
# found match!
# best distance:	 3
# input:	 Abandon Kansas Give & Take
# found:	 Abandon Kansas Give And Take
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abandon Kansas Heaven Come My Way
# found:	 Abandon Kansas Heaven Come My Way
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abandon Kansas I Wonder If It's Me
# found:	 Abandon Kansas I Wonder If It's Me
# ====================
#
# no track found for Abandon Kansas I'll Take It From Here
# ===================
# found match!
# best distance:	 0
# input:	 Abandon Kansas Make Believe
# found:	 Abandon Kansas Make Believe
# ====================
#
# no track found for Abandon Kansas No Place Like Home
# ===================
# found match!
# best distance:	 0
# input:	 Abandon Kansas The Chase
# found:	 Abandon Kansas The Chase
# ====================
#
# no track found for Abandon Kansas The Earth Falls Asleep (Acoustic Version)
# ===================
# found match!
# best distance:	 0
# input:	 Abandon Kansas The Golden State
# found:	 Abandon Kansas The Golden State
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abandon Kansas The Harder They Fall
# found:	 Abandon Kansas The Harder They Fall
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abandon Kansas Turn It To Gold
# found:	 Abandon Kansas Turn It to Gold
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abandon Kansas We're All Going Somewhere
# found:	 Abandon Kansas We're All Going Somewhere
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abandon Kansas You Build A Wall (Acoustic)
# found:	 Abandon Kansas You Build a Wall (Acoustic)
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abandon Known
# found:	 Abandon Known
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abandon Let Go
# found:	 Abandon Let Go
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abandon Live It Out
# found:	 Abandon Live It Out
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abandon Piles of Pigs
# found:	 Abandon Piles Of Pigs
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abandon Pitch Black Hole
# found:	 Abandon Pitch Black Hole
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abandon Providence
# found:	 Abandon Providence
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abandon S.O.S.
# found:	 Abandon S.O.S.
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abandon Safe In Your Arms
# found:	 Abandon Safe In Your Arms
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abandon Somnambulistic
# found:	 Abandon Somnambulistic
# ====================
#
# no track found for Abandon Stillborn Persistence
# no track found for Abandon Stillborn Persistence...
# no track found for Abandon The Past Blind Dreamer
# no track found for Abandon The Shore With You In Mind
# ===================
# found match!
# best distance:	 0
# input:	 Abandon To Defy
# found:	 Abandon To Defy
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abandon Trauma Is the Trigger
# found:	 Abandon Trauma Is The Trigger
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abandon Under Fire
# found:	 Abandon Under Fire
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abandon Will Gladly Perish
# found:	 Abandon Will Gladly Perish
# ====================
#
# no track found for Abandoned  カセット 時間のパワー
# no track found for Abandoned  カセット 無限のサンセットドリーム
# no track found for Abandoned Asylum They Watch as We Pass By
# no track found for Abandoned Blue Eyes That Kill
# ===================
# found match!
# best distance:	 0
# input:	 Abandoned By Bears Homegrown
# found:	 Abandoned By Bears Homegrown
# ====================
#
# no track found for Abandoned Grave Intestine Goulash
# no track found for Abandoned Hotels Nätive
# no track found for Abandoned Interstate Hitting Targets
# ===================
# found match!
# best distance:	 0
# input:	 Abandoned Killed By Faith
# found:	 Abandoned Killed By Faith
# ====================
#
# no track found for Abandoned No Sympathy
# no track found for Abandoned Places Parthoris
# ===================
# found match!
# best distance:	 0
# input:	 Abandoned Pools Armed To The Teeth
# found:	 Abandoned Pools Armed To The Teeth
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abandoned Pools Arms Race
# found:	 Abandoned Pools Arms Race
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abandoned Pools Blood
# found:	 Abandoned Pools Blood
# ====================
#
# no track found for Abandoned Pools Clone High Theme
# no track found for Abandoned Pools Clone High Theme (Extended Ver
# no track found for Abandoned Pools Clone High Theme (extended version)
# ===================
# found match!
# best distance:	 0
# input:	 Abandoned Pools Fluorescein
# found:	 Abandoned Pools Fluorescein
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abandoned Pools Goodbye Song
# found:	 Abandoned Pools Goodbye Song
# ====================
#
# no track found for Abandoned Pools Hunting (The Universe Breaks My Heart)
# ===================
# found match!
# best distance:	 0
# input:	 Abandoned Pools Hype Is the Enemy
# found:	 Abandoned Pools Hype Is The Enemy
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abandoned Pools Lethal Killers
# found:	 Abandoned Pools Lethal Killers
# ====================
#
# no track found for Abandoned Pools Maybe Then Someday
# ===================
# found match!
# best distance:	 0
# input:	 Abandoned Pools Mercy Kiss
# found:	 Abandoned Pools Mercy Kiss
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abandoned Pools Monster
# found:	 Abandoned Pools Monster
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abandoned Pools Never
# found:	 Abandoned Pools Never
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abandoned Pools Occupy
# found:	 Abandoned Pools Occupy
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abandoned Pools Pep Talk
# found:	 Abandoned Pools Pep Talk
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abandoned Pools Rabble
# found:	 Abandoned Pools Rabble
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abandoned Pools Ruin Your Life
# found:	 Abandoned Pools Ruin Your Life
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abandoned Pools Sailing Seas
# found:	 Abandoned Pools Sailing Seas
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abandoned Pools Seed
# found:	 Abandoned Pools Seed
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abandoned Pools Sooner or Later
# found:	 Abandoned Pools Sooner or Later
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abandoned Pools Start Over
# found:	 Abandoned Pools Start Over
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abandoned Pools Sublime Currency
# found:	 Abandoned Pools Sublime Currency
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abandoned Pools Suburban Muse
# found:	 Abandoned Pools Suburban Muse
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abandoned Pools Sunny Day
# found:	 Abandoned Pools Sunny Day
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abandoned P
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abby Gundersen Farewell Summer
# found:	 Abby Gundersen Farewell Summer
# ====================
#
# +++++++++++++++++++
# no match for Abby Halo
#
# input:	 Abby Halo
# found:	 ABBY Halo - Thyladomid Remix
# +++++++++++++++++++
# ===================
# found match!
# best distance:	 0
# input:	 Abby Hush
# found:	 ABBY Hush
# ====================
#
# no track found for Abby Mallard And Runt Of The Litter Wannabe
# ===================
# found match!
# best distance:	 3
# input:	 Abby Streets (Wraetlic Remix)
# found:	 Abby Streets - Wraetlic Remix
# ====================
#
# ===================
# found match!
# best distance:	 3
# input:	 Abby This Song Remains Through All (Clockwork Remix)
# found:	 Abby This Song Remains Through All - Clockwork Remix
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abby Time Is Golden
# found:	 ABBY Time Is Golden
# ====================
#
# no track found for Abby Tom Disco
# ===================
# found match!
# best distance:	 0
# input:	 Abby Travis So Far Away
# found:	 Abby Travis So Far Away
# ====================
#
# no track found for Abby We dont worry
# ===================
# found match!
# best distance:	 3
# input:	 Abby Webster Drunk and Pretty
# found:	 Abby Webster Drunk & Pretty
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abby Webster Hot Air Balloons
# found:	 Abby Webster Hot Air Balloons
# ====================
#
# no track found for Abby Webster Lonewolf
# ===================
# found match!
# best distance:	 0
# input:	 Abby Webster Madness
# found:	 Abby Webster Madness
# ====================
#
# no track found for Abby Webster Punch A Scientist
# ===================
# found match!
# best distance:	 0
# input:	 Abby Webster Young Men
# found:	 Abby Webster Young Men
# ====================
#
# no track found for Abby like a star
# ===================
# found match!
# best distance:	 0
# input:	 Abc Alphabet Sounds App Alphabet Song
# found:	 Abc Alphabet Sounds App Alphabet Song
# ====================
#
# no track found for Abcess Exil Hav Av Hat
# no track found for Abcess Exil Lånad Tid
# ===================
# found match!
# best distance:	 0
# input:	 Abd Al Malik Allogène (j'suis un stremon)
# found:	 Abd Al Malik Allogène (j'suis un stremon)
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abd Al Malik Gibraltar
# found:	 Abd Al Malik Gibraltar
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abd Al Malik L'Alchimiste
# found:	 Abd Al Malik L'alchimiste
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abd Al Malik Les Autres
# found:	 Abd Al Malik Les autres
# ====================
#
# no track found for Abd Al Malik Ma Jolie
# ===================
# found match!
# best distance:	 0
# input:	 Abd Al Malik Paris Mais ...
# found:	 Abd Al Malik Paris mais ...
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abd Al Malik Soldat De Plomb
# found:	 Abd Al Malik Soldat de plomb
# ====================
#
# no track found for Abdallah Al Rowaishid Elly Nasak
# no track found for Abdallah Chahine Halalayya
# ===================
# found match!
# best distance:	 0
# input:	 Abdel Ali Slimani Moi et Toi
# found:	 Abdel Ali Slimani Moi et Toi
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abdel Ali Slimani Mraya
# found:	 Abdel Ali Slimani Mraya
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abdel Aziz El Mubarak Tarig Ash-Shoag
# found:	 Abdel Aziz El Mubarak Tarig Ash-shoag
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abdel Gadir Salim A'abir Sikkah
# found:	 Abdel Gadir Salim A'abir Sikkah
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Ab
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abdi Behravanfar Be Saram Zad
# found:	 Abdi Behravanfar Be Saram Zad
# ====================
#
# no track found for Abdi Yolo (prod. Psymun)
# no track found for Abdo Shamakh Mapenzi Ya Ashiki (Nairobi, early 50's)
# no track found for Abdol Hossein Mokhtabad Avaz -e Bayat -e Esfahan
# ===================
# found match!
# best distance:	 3
# input:	 Abdomen Burst Moments Of Love (Aeron Aether Remix)
# found:	 Abdomen Burst Moments Of Love - Aeron Aether Remix
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abdomen United
# found:	 Abdomen United
# ====================
#
# no track found for Abdominal & DJ Fase Fast Food (DJ Format remix)
# no track found for Abdominal & DJ Fase Fly Antics
# no track found for Abdominal & DJ Fase The Best Posse Cut You Ever Heard (Featuring Dan-E-O, D-Sisive, Fatski, Kamau, The Grand I Am Perial, Esoteric & Arcee)
# ===================
# found match!
# best distance:	 0
# input:	 Abdominal Abdominal Workout
# found:	 Abdominal Abdominal Workout
# ====================
#
# no track found for Abdominal Beatbox S**t (feat. Oral B)
# ===================
# found match!
# best distance:	 0
# input:	 Abdominal Big Track
# found:	 Abdominal Big Track
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abdominal Breathe Later
# found:	 Abdominal Breathe Later
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abdominal Countdown
# found:	 Abdominal Countdown
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abdominal Flyer Antics
# found:	 Abdominal Flyer Antics
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abdominal Girl Shit
# found:	 Abdominal Girl Shit
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abdominal Heaven's Demon
# found:	 Abdominal Heaven's Demon
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abdominal Open Relationship
# found:	 Abdominal Open Relationship
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abdominal Pedal Pusher
# found:	 Abdominal Pedal Pusher
# ====================
#
# no track found for Abdominal Pedal Pusher (Commonwealth Remix)
# no track found for Abdominal Pedal Pusher (feat. the Obliques) (Live)
# ===================
# found match!
# best distance:	 0
# input:	 Abdominal Radio Friendly
# found:	 Abdominal Radio Friendly
# ====================
#
# no track found for Abdominal T-Ode
# ===================
# found match!
# best distance:	 0
# input:	 Abdominal The Escape
# found:	 Abdominal The Escape
# ====================
#
# +++++++++++++++++++
# no match for Abdominal Ugly Brothers
#
# input:	 Abdominal Ugly Brothers
# found:	 DJ Format Ugly Brothers
# +++++++++++++++++++
# no track found for Abdominal Vicious Battle Raps
# ===================
# found match!
# best distance:	 2
# input:	 Abdominal Walk Left, Stand Right
# found:	 Abdominal Walk Left / Stand Right
# ====================
#
# ===================
# found match!
# best distance:	 2
# input:	 Abdominal Walk Left/stand Right
# found:	 Abdominal Walk Left / Stand Right
# ====================
#
# no track found for Abdonimal/DJ Format/D-Sisive 3Ft Deep
# no track found for Abdou Chaijib
# ===================
# found match!
# best distance:	 0
# input:	 Abdou El Omari Zifaf Filfada
# found:	 Abdou El Omari Zifaf Filfada
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abdou No Patience.
# found:	 Abdou No Patience.
# ====================
#
# no track found for Abdou Yahaya Bori Possesion Music
# ===================
# found match!
# best distance:	 0
# input:	 Abdoujaparov Emergency Medical Hologram
# found:	 Abdoujaparov Emergency Medical Hologram
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abdoujaparov Fish Face
# found:	 Abdoujaparov Fish Face
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Abdoulaye Cisse Kodjougou
# found:	 Abdoulaye Cisse Kodjougou
# ====================
#
# no track found for Abdoulaye Diabate Balani
# ===================
# found match!
# best distance:	 0
# input:	 Abdoulaye Diabaté N'Dyaba
# found:	 Abdoulaye Diabaté N'dyaba
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 
# ===================
# found match!
# best distance:	 0
# input:	 Absolute Body Control Into The Light
# found:	 Absolute Body Control Into The Light
# ====================
#
# no track found for Absolute Body Control Into The Light (Beat-less version)
# ===================
# found match!
# best distance:	 1
# input:	 Absolute Body Control Is There An Exit
# found:	 Absolute Body Control Is There An Exit?
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Absolute Body Control Is There An Exit?
# found:	 Absolute Body Control Is There An Exit?
# ====================
#
# no track found for Absolute Body Control Late At Night
# ===================
# found match!
# best distance:	 0
# input:	 Absolute Body Control Love At First Sight
# found:	 Absolute Body Control Love At First Sight
# ====================
#
# no track found for Absolute Body Control Me And My desire
# ===================
# found match!
# best distance:	 0
# input:	 Absolute Body Control Melting Away
# found:	 Absolute Body Control Melting Away
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Absolute Body Control Never Seen
# found:	 Absolute Body Control Never Seen
# ====================
#
# no track found for Absolute Body Control Numbers 10
# no track found for Absolute Body Control Numbers 11 (Silhouette)
# no track found for Absolute Body Control Numbers 15
# no track found for Absolute Body Control Precious
# ===================
# found match!
# best distance:	 0
# input:	 Absolute Body Control Saturnia Calling
# found:	 Absolute Body Control Saturnia Calling
# ====================
#
# no track found for Absolute Body Control Shake
# ===================
# found match!
# best distance:	 0
# input:	 Absolute Body Control Shattered Illusion
# found:	 Absolute Body Control Shattered Illusion
# ====================
#
# no track found for Absolute Body Control So Hard (live)
# ===================
# found match!
# best distance:	 0
# input:	 Absolute Body Control So Obvious
# found:	 Absolute Body Control So Obvious
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Absolute Body Control Sorrow
# found:	 Absolute Body Control Sorrow
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Absolute Body Control Stardust Fever
# found:	 Absolute Body Control Stardust Fever
# ====================
#
# no track found for Absolute Body Control Suffer In Silence
# ===================
# found match!
# best distance:	 0
# input:	 Absolute Body Control Surrender No Resistance
# found:	 Absolute Body Control Surrender No Resistance
# ====================
#
# ===================
# found match!
# best distance:	 0
# input:	 Absolute Body Control Talking To The Man
# found:	 Absolute Body Control Talking To The Man
# ====================
#
# no track found for Absolute Body Control Tanzmusik
# no track found for Absolute Body Control Terminus
# no track found for Absolute Body Control The Man I Wanna Be
# no track found for Absolute Body Control Total Control
# ===================
# found match!
# best distance:	 0
# input:	 Absolute Body Control Touch Your Skin
# found:	 Absolute Body Control Touch Your Skin
# ====================
#
# no track found for Absolute Body Control Turning Around
# no track found for Absolute Body Control Waving Hands
# no track found for Absolute Body Control Weaving Hands
# ===================
# found match!
# best distance:	 0
# input:	 Absolute Body Control What Took You So Long?
# found:	 Absolute Body Control What Took You So Long?
# ====================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-50-cd2a236749dc> in <module>
#       2 for track in sample_tracks:
#       3     track = track[0]
# ----> 4     feature = get_features(track, tolerance=5)
#       5     time.sleep(.1)
#       6     if feature:  # if not None
#
# <ipython-input-34-39a1079a4778> in get_features(artist_track, tolerance)
#      61         print()
#      62         uri = best_track['uri']
# ---> 63         features = sp.audio_features([uri])
#      64         return best_track_artist_track, features
#      65
#
# ~/anaconda3/lib/python3.7/site-packages/spotipy/client.py in audio_features(self, tracks)
#     827         else:
#     828             tlist = [self._get_id('track', t) for t in tracks]
# --> 829             results = self._get('audio-features/?ids=' + ','.join(tlist))
#     830         # the response has changed, look for the new style first, and if
#     831         # its not there, fallback on the old style
#
# ~/anaconda3/lib/python3.7/site-packages/spotipy/client.py in _get(self, url, args, payload, **kwargs)
#     144         while retries > 0:
#     145             try:
# --> 146                 return self._internal_call('GET', url, payload, kwargs)
#     147             except SpotifyException as e:
#     148                 retries -= 1
#
# ~/anaconda3/lib/python3.7/site-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     106         if self.trace_out:
#     107             print(url)
# --> 108         r = self._session.request(method, url, headers=headers, proxies=self.proxies, **args)
#     109
#     110         if self.trace:  # pragma: no cover
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     341         # Trigger any extra validation we need to do.
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#     345             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     837         # Force connect early to allow us to validate the connection.
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#     841         if not conn.is_verified:
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     299     def connect(self):
#     300         # Add certificate verification
# --> 301         conn = self._new_conn()
#     302         hostname = self.host
#     303
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     157         try:
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#     161         except SocketTimeout as e:
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      68             if source_address:
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#      72
#
# KeyboardInterrupt:

# %% [raw]
# connection.rollback()

# %%
connection.commit()
